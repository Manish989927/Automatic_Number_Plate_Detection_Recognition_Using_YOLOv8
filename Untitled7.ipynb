# %% [markdown]
# <a href="https://colab.research.google.com/github/Manish989927/Automatic_Number_Plate_Detection_Recognition_Using_YOLOv8/blob/master/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Sep 18 15:00:04 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   57C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# ...
# 100% 6.23M/6.23M [00:00<00:00, 8.74MB/s]
#
# 2023-09-18 15:00:25.188925: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-18 15:00:26.074104: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# ...
# 100% 104k/104k [00:00<00:00, 38.4MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 70.5ms
# Speed: 0.5ms pre-process, 70.5ms inference, 343.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
# %cd {HOME}
Image(filename='runs/detect/predict/dog.jpeg', height=600)
# Out:
# /content

# %%
# !gdown https://drive.google.com/u/0/uc?id=1jFh8DKV2mdiAyxCje7kkzXZhtWLDBz0A&export=download
# !unzip  /content/LicensePlate_v2.v2-two.yolov5pytorch.zip  -d data
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1jFh8DKV2mdiAyxCje7kkzXZhtWLDBz0A
# To: /content/LicensePlate_v2.v2-two.yolov5pytorch.zip
# 100% 16.8M/16.8M [00:00<00:00, 150MB/s]
# Archive:  /content/LicensePlate_v2.v2-two.yolov5pytorch.zip
#  extracting: data/README.dataset.txt
#  extracting: data/README.roboflow.txt
#  extracting: data/data.yaml
#    creating: data/test/
#    creating: data/test/images/
#  extracting: data/test/images/1649292507297_jpg.rf.bd0e5ebeb8fc2f0566343ead87672b23.jpg
#  extracting: data/test/images/1649292507302_jpg.rf.26f648e8ec62988c2b50a38402bf56e2.jpg
#  extracting: data/test/images/1649292507302_jpg.rf.53720ffda86cf8f55fa26f741a3ee9d3.jpg
#  extracting: data/test/images/1649292507305_jpeg.rf.632dbb51471f7f8671343a085894f848.jpg
#  extracting: data/test/images/1649292507307_jpg.rf.9fdd7a627bf956e3223f70741a0ad496.jpg
#  extracting: data/test/images/1649292507312_jpg.rf.009c460516fc8ee07e295216382f962c.jpg
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# 2023-09-18 15:00:45.350754: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-18 15:00:46.207029: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 61.9ms
# Speed: 0.5ms pre-process, 61.9ms inference, 119.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %%
# %cd {HOME}
Image(filename='runs/detect/predict/dog.jpeg', height=600)
# Out:
# /content

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data=/content/data/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# /content
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.25 source=/content/data/test/images save=True
# Out:
# /content
# 2023-09-18 15:23:47.239932: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-18 15:23:48.357007: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# image 1/83 /content/data/test/images/1649292507297_jpg.rf.bd0e5ebeb8fc2f0566343ead87672b23.jpg: 608x800 1 license plate, 65.2ms
# image 2/83 /content/data/test/images/1649292507302_jpg.rf.26f648e8ec62988c2b50a38402bf56e2.jpg: 544x800 1 license plate, 62.1ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/runs/detect/predict3/*.jpg')[:10]:
      display(Image(filename=image_path, width=600))
      print("\n")
